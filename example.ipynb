# %%
from matchupplotter import MatchupPlotter
from importlib import reload

# %%
## woba_value for woba. delta_run_exp

matchup_plotter = MatchupPlotter("Davis", "Martin", "Ben", "Rice", "L", "R", "FF")
matchup_plotter.plot_matchup()
# Out:
# 2025-04-01 2025-08-28
# Gathering Player Data
# Gathering Player Data
# Retrieved data for pitcher: Davis Martin
# Retrieved data for batter: Ben Rice
# Filtered data for pitcher Davis Martin and batter Ben Rice.
# /Users/matthewgillies/mlb_plots/matchupplotter.py:120: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
