# %%
from matchupplotter import MatchupPlotter
from importlib import reload

# %%
matchup_plotter = MatchupPlotter("Adrian", "Houser", "Dansby", "Swanson", "R", "R", "SI")
matchup_plotter.plot_matchup()
# Out:
# 2025-04-01 2025-07-25
# Gathering Player Data
# Gathering Player Data
# Retrieved data for pitcher: Adrian Houser
# Retrieved data for batter: Dansby Swanson
# Filtered data for pitcher Adrian Houser and batter Dansby Swanson.
# count    62.000000
# mean      0.317839
# std       0.222304
# min       0.100000
# 25%       0.100000
# 50%       0.237500
# 75%       0.600000
# max       0.600000
# Name: estimated_woba_using_speedangle, dtype: float64
# count    74.000000
# mean      0.296015
# std       0.265068
# min       0.000000
# 25%       0.083000
# 50%       0.215000
# 75%       0.433500
# max       0.901000
# Name: estimated_woba_using_speedangle, dtype: float64
